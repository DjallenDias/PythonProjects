# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
# %matplotlib inline

# %%
imagem = Image.open("img/smiling_cats")
imagem_vetor = np.asarray(imagem) # transformando a imagem em matriz
imagem_vetor.shape
# Out:
# (6000, 4000, 3)

# %%
plt.imshow(imagem_vetor)

# %%
copia_img = imagem_vetor.copy()

# %%
#RGB - Vermelho - 0, Verde - 1, Blue - 2
plt.imshow(copia_img[:,:,0], cmap='gray') # copia_img[:,:,0] o numero 0 se referencia ao canal RGB escolhido

# %%
copia_img = imagem_vetor.copy()
copia_img[:,:,0] = 255
copia_img[:,:,2] = 0
plt.imshow(copia_img[:,:,:])
